# %% [markdown]
# <a href="https://colab.research.google.com/github/4522Dev/eda/blob/main/DA_1_Predictive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load necessary libraries
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Load the earthquake data
df = pd.read_csv('earthquake_data.csv')

# Select features for clustering
X = df[['latitude', 'longitude']]

# Define the number of clusters
num_clusters = 5

# Initialize KMeans
kmeans = KMeans(n_clusters=num_clusters, random_state=0)

# Fit the model and predict the clusters
df['cluster'] = kmeans.fit_predict(X)

# Set plot size
plt.figure(figsize=(12, 8))

# Create a scatter plot with Seaborn
sns.scatterplot(x='longitude', y='latitude', hue='cluster', palette='viridis', data=df, s=100, alpha=0.6, edgecolor='w')

# Add labels and title
plt.title('Earthquake Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Cluster')
plt.grid(True)

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
