# %% [markdown]
# <a href="https://colab.research.google.com/github/4522Dev/eda/blob/main/Module2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 2

# %%
import pandas as pd
import numpy as np

# %%
dataset= pd.read_csv('https://raw.githubusercontent.com/salemprakash/EDA/main/Data/student-mat.csv')
dataset
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
dataset.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
df1 = dataset.iloc[:len(dataset)//2]
df2 = dataset.iloc[len(dataset)//2:]
df3 = pd.concat([df1,df2],ignore_index=True)
df3
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     school  sex   age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP    F  18.0       U     GT3       A   4.0   4.0  at_home   teacher
# 1       GP    F  17.0       U     GT3       T   1.0   1.0  at_home     other
# 2       GP    F  15.0       U     LE3       T   1.0   1.0  at_home     other
# 3       GP    F  15.0       U     GT3       T   4.0   2.0   health  services
# 4       GP    F  16.0       U     GT3       T   3.0   3.0    other     other
# ..     ...  ...   ...     ...     ...     ...   ...   ...      ...       ...
# 390    NaN  NaN   NaN     NaN     NaN     NaN   NaN   NaN      NaN       NaN
# 391    NaN  NaN   NaN     NaN     NaN     NaN   NaN   NaN      NaN       NaN
# 392    NaN  NaN   NaN     NaN     NaN     NaN   NaN   NaN      NaN       NaN
# 393    NaN  NaN   NaN     NaN     NaN     NaN   NaN   NaN      NaN       NaN
# 394    NaN  NaN   NaN     NaN     NaN     NaN   NaN   NaN      NaN       NaN
#
# ...

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df4=pd.concat([df1,df2],ignore_index=False)
df4
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df5=df1.merge(df2,how='inner')
df5
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
df6=df1.merge(df2,how='outer')
df6
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df7=df1.merge(df2,how='left')
df7
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 192     GP   M   17       U     GT3       T     1     2   at_home  services
# 193     GP   M   16       R     GT3       T     3     3  services  services
# 194     GP   M   16       U     GT3       T     2     3     other     other
# 195     GP   F   17       U     LE3       T     2     4  services  services
# 196     GP   M   17       U     GT3       T     4     4  services   teacher
#
# ...

# %%
dataset['total_time_spent']=dataset['studytime']+dataset['traveltime']
dataset
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
dataset['sex'].value_counts()
# Out:
# sex
# F    208
# M    185
# Name: count, dtype: int64

# %%
dataset.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
data = np.arange(15).reshape((3,5))
indexers = ['Rainfall', 'Humidity', 'Wind']
dframe1 = pd.DataFrame(data, index=indexers, columns=['Bergen', 'Oslo', 'Trondheim', 'Stavanger', 'Kristiansand'])
dframe1
# Out:
#           Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall       0     1          2          3             4
# Humidity       5     6          7          8             9
# Wind          10    11         12         13            14

# %%
stacked = df3.stack()
stacked
# Out:
# 0    school       GP
#      sex           F
#      age          18
#      address       U
#      famsize     GT3
#                 ...
# 394  health        5
#      absences      5
#      G1            8
#      G2            9
#      G3            9
# Length: 13029, dtype: object

# %%
stacked.unstack()
# Out:
#     school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  ...  \
# 0       GP   F  18       U     GT3       A    4    4   at_home   teacher  ...
# 1       GP   F  17       U     GT3       T    1    1   at_home     other  ...
# 2       GP   F  15       U     LE3       T    1    1   at_home     other  ...
# 3       GP   F  15       U     GT3       T    4    2    health  services  ...
# 4       GP   F  16       U     GT3       T    3    3     other     other  ...
# ..     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...  ...
# 390     MS   M  20       U     LE3       A    2    2  services  services  ...
# 391     MS   M  17       U     LE3       T    3    1  services  services  ...
# 392     MS   M  21       R     GT3       T    1    1     other     other  ...
# 393     MS   M  18       R     LE3       T    3    2  services     other  ...
# 394     MS   M  19       U     LE3       T    1    1     other   at_home  ...
#
# ...

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 192    False
# 193    False
# 194    False
# 195    False
# 196    False
# Length: 197, dtype: bool

# %%
df1.drop_duplicates()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 192     GP   M   17       U     GT3       T     1     2   at_home  services
# 193     GP   M   16       R     GT3       T     3     3  services  services
# 194     GP   M   16       U     GT3       T     2     3     other     other
# 195     GP   F   17       U     LE3       T     2     4  services  services
# 196     GP   M   17       U     GT3       T     4     4  services   teacher
#
# ...

# %%
df1['sex']= 'F'
df1
df1.drop_duplicates(['sex'])
# Out:
# <ipython-input-20-a8200ae6cb3b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['sex']= 'F'
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 0      4        3      4     1     1      3        6  5  6  6
#
# [1 rows x 33 columns]

# %%
dframe1.replace(to_replace=13,value=np.nan)
# Out:
#           Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall       0     1          2        3.0             4
# Humidity       5     6          7        8.0             9
# Wind          10    11         12        NaN            14

# %%
dframe1.replace(to_replace=[13,14],value=np.nan)
# Out:
#           Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall       0     1          2        3.0           4.0
# Humidity       5     6          7        8.0           9.0
# Wind          10    11         12        NaN           NaN

# %%
dframe1['Bergen'] =np.nan
dframe1.loc['Air Pollution'] = np.arange(10,15)
dframe1.loc['Rainfall'] = np.nan
dframe1['Oslo'] = np.nan
dframe1['Bergen']['Rainfall'] = 30
dframe1
# Out:
#                Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall         30.0   NaN        NaN        NaN           NaN
# Humidity          NaN   NaN        7.0        8.0           9.0
# Wind              NaN   NaN       12.0       13.0          14.0
# Air Pollution    10.0   NaN       12.0       13.0          14.0

# %%
dframe1.isnull()
# Out:
#                Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall        False  True       True       True          True
# Humidity         True  True      False      False         False
# Wind             True  True      False      False         False
# Air Pollution   False  True      False      False         False

# %%
dframe1.notnull()
# Out:
#                Bergen   Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall         True  False      False      False         False
# Humidity        False  False       True       True          True
# Wind            False  False       True       True          True
# Air Pollution    True  False       True       True          True

# %%
dframe1.isnull().sum()
# Out:
# Bergen          2
# Oslo            4
# Trondheim       1
# Stavanger       1
# Kristiansand    1
# dtype: int64

# %%
dframe1.isnull().sum().sum()
# Out:
# 9

# %%
dframe1.count()
# Out:
# Bergen          2
# Oslo            0
# Trondheim       3
# Stavanger       3
# Kristiansand    3
# dtype: int64

# %%
dframe1.Bergen[dframe1.Bergen.notnull()]
# Out:
# Rainfall         30.0
# Air Pollution    10.0
# Name: Bergen, dtype: float64

# %%
dframe1.dropna()
# Out:
# Empty DataFrame
# Columns: [Bergen, Oslo, Trondheim, Stavanger, Kristiansand]
# Index: []

# %%
dframe1.dropna(how='all')
# Out:
#                Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall         30.0   NaN        NaN        NaN           NaN
# Humidity          NaN   NaN        7.0        8.0           9.0
# Wind              NaN   NaN       12.0       13.0          14.0
# Air Pollution    10.0   NaN       12.0       13.0          14.0

# %%
dframe1.dropna(how='all',axis=1)
# Out:
#                Bergen  Trondheim  Stavanger  Kristiansand
# Rainfall         30.0        NaN        NaN           NaN
# Humidity          NaN        7.0        8.0           9.0
# Wind              NaN       12.0       13.0          14.0
# Air Pollution    10.0       12.0       13.0          14.0

# %%
dframe1.dropna(thresh=2,axis=1)
# Out:
#                Bergen  Trondheim  Stavanger  Kristiansand
# Rainfall         30.0        NaN        NaN           NaN
# Humidity          NaN        7.0        8.0           9.0
# Wind              NaN       12.0       13.0          14.0
# Air Pollution    10.0       12.0       13.0          14.0

# %%
ar1=np.array([100,200,np.nan,300])
ser1=pd.Series(ar1)
ar1.mean(),ser1.mean()
# Out:
# (nan, 200.0)

# %%
ser2 = dframe1.Bergen
ser2.sum()
# Out:
# 40.0

# %%
ser2.cumsum()
# Out:
# Rainfall         30.0
# Humidity          NaN
# Wind              NaN
# Air Pollution    40.0
# Name: Bergen, dtype: float64

# %%
filldataframe=dframe1.fillna(0)
filldataframe
# Out:
#                Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall         30.0   0.0        0.0        0.0           0.0
# Humidity          0.0   0.0        7.0        8.0           9.0
# Wind              0.0   0.0       12.0       13.0          14.0
# Air Pollution    10.0   0.0       12.0       13.0          14.0

# %%
dframe1.mean()
filldataframe.mean()
# Out:
# Bergen          10.00
# Oslo             0.00
# Trondheim        7.75
# Stavanger        8.50
# Kristiansand     9.25
# dtype: float64

# %%
dframe1.fillna(method='ffill')
# Out:
# <ipython-input-39-ac1efdf2eccf>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dframe1.fillna(method='ffill')
#                Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall         30.0   NaN        NaN        NaN           NaN
# Humidity         30.0   NaN        7.0        8.0           9.0
# Wind             30.0   NaN       12.0       13.0          14.0
# Air Pollution    10.0   NaN       12.0       13.0          14.0

# %%
dframe1.fillna(method='bfill')
# Out:
# <ipython-input-40-5e39827b3e85>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dframe1.fillna(method='bfill')
#                Bergen  Oslo  Trondheim  Stavanger  Kristiansand
# Rainfall         30.0   NaN        7.0        8.0           9.0
# Humidity         10.0   NaN        7.0        8.0           9.0
# Wind             10.0   NaN       12.0       13.0          14.0
# Air Pollution    10.0   NaN       12.0       13.0          14.0

# %%
Marks=[12,23,34,45,56,67,78,89,90,10]
bins=[0,20,40,60,80,100]
grade=pd.cut(Marks,bins)
grade
# Out:
# [(0, 20], (20, 40], (20, 40], (40, 60], (40, 60], (60, 80], (60, 80], (80, 100], (80, 100], (0, 20]]
# Categories (5, interval[int64, right]): [(0, 20] < (20, 40] < (40, 60] < (60, 80] < (80, 100]]

# %%
pd.value_counts(grade)
# Out:
# <ipython-input-42-b0de5cbf5331>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(grade)
# (0, 20]      2
# (20, 40]     2
# (40, 60]     2
# (60, 80]     2
# (80, 100]    2
# Name: count, dtype: int64

# %%
bin_names=['F','D','C','B','A']
grade=pd.cut(Marks,bins,labels=bin_names)
grade
# Out:
# ['F', 'D', 'D', 'C', 'C', 'B', 'B', 'A', 'A', 'F']
# Categories (5, object): ['F' < 'D' < 'C' < 'B' < 'A']

# %%
pd.cut(np.random.randn(50),6,precision=2)
# Out:
# [(-0.011, 0.66], (0.66, 1.33], (1.33, 2.0], (0.66, 1.33], (0.66, 1.33], ..., (-0.68, -0.011], (-0.68, -0.011], (0.66, 1.33], (0.66, 1.33], (-0.68, -0.011]]
# Length: 50
# Categories (6, interval[float64, right]): [(-2.03, -1.35] < (-1.35, -0.68] < (-0.68, -0.011] <
#                                            (-0.011, 0.66] < (0.66, 1.33] < (1.33, 2.0]]

# %%
random_integers=np.random.rand(400)
quartered=pd.qcut(random_integers,4)
quartered
# Out:
# [(0.00234, 0.254], (0.486, 0.742], (0.486, 0.742], (0.742, 0.999], (0.742, 0.999], ..., (0.00234, 0.254], (0.486, 0.742], (0.254, 0.486], (0.486, 0.742], (0.254, 0.486]]
# Length: 400
# Categories (4, interval[float64, right]): [(0.00234, 0.254] < (0.254, 0.486] < (0.486, 0.742] <
#                                            (0.742, 0.999]]

# %%
pd.value_counts(quartered)
# Out:
# <ipython-input-50-278e496f70ef>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(quartered)
# (0.00234, 0.254]    100
# (0.254, 0.486]      100
# (0.486, 0.742]      100
# (0.742, 0.999]      100
# Name: count, dtype: int64

# %%
Timespent= dataset['total_time_spent']
Timespent[np.abs(Timespent)>5]
# Out:
# 11     6
# 69     6
# 70     6
# 76     6
# 95     6
# 108    8
# 134    6
# 140    6
# 164    6
# 204    6
# 228    6
# 282    6
# 293    6
# 334    6
# 375    7
# Name: total_time_spent, dtype: int64

# %%
dataset[np.abs(Timespent)>5]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 69      GP   F   15       R     LE3       T     3     1     other     other
# 70      GP   M   16       U     GT3       T     3     1     other     other
# 76      GP   M   15       U     GT3       ?     4     0   teacher     other
# 95      GP   F   15       R     GT3       T     1     1   at_home     other
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# 140     GP   M   15       U     GT3       T     4     3   teacher  services
# 164     GP   M   17       R     LE3       T     1     1     other  services
# 204     GP   F   16       R     GT3       T     2     2  services  services
# 228     GP   M   18       U     LE3       T     2     1   at_home     other
# ...
